# %% [markdown]
# input function

# %%
location=input("enter you location:")
print("My location:",location)
# Out:
# My location: kollam

# %%
height=float(input())        
print(height)
print(type(height))
# Out:
# 176.0
# <class 'float'>

# %%
age=int(input("enter age:"))
print("Age:",age)
print(type(age))
# Out:
# Age: 23
# <class 'int'>

# %%
is_student=bool(input("Are you a student?"))
print(is_student)
print(type(is_student))
# Out:
# False
# <class 'bool'>

# %%
company_name=input("Enter company name:")
company_loc=input("Company location:")
experience=int(input("Experience:"))
salary=int(input("Salary:"))
# print("My company name is ",company_name,"located at ",company_loc,".I have ",experience,"years of experience","and my current salary is ",salary)
print(f"My company name is {company_name} located at {company_loc} .I have {experience} years of experience and my current salary is {salary}")
# Out:
# My company name is sos located at calicut .I have 3 years of experience and my current salary is 15000

# %% [markdown]
# string format

# %%
name=input("enter name:")
age=int(input("enter age:"))
print("my name is {} and i'm {} years old".format(name,age))
# Out:
# my name is mia and i'm 19 years old

# %% [markdown]
# f string

# %%
name=input("enter name:")
marks=int(input("enter marks:"))
print(f"{name} scored {marks} marks")
# Out:
# arya scored 23 marks

# %%
python_marks=int(input("enter python marks:"))
xl_marks=int(input("enter xl marks:"))
sql_marks=int(input("enter sql marks:"))
total_marks=python_marks+xl_marks+sql_marks
avg=total_marks/3
print(f"Your Total marks is {total_marks} and average marks is {avg}")
# Out:
# Your Total marks is 66 and average marks is 22.0
