# %% [markdown]
# ### if condition

# %%
age=20
if age>18:
   print("eligible to vote")
# Out:
# eligible to vote

# %%
num=int(input("enter a number:"))
if num>0:
    print("positive number")
# Out:
# positive number

# %%
x=int(input("enter number:"))
if x>5:print(f"{x} is greater than 5")
# Out:
# 6 is greater than 5

# %% [markdown]
# ### if-else condition

# %%
age=int(input("enter age:"))
if age>=18:
    print("eligible to vote")
else:
    print('not eligible to vote')
# Out:
# not eligible to vote

# %%
marks=int(input("enter marks:"))
if marks>40:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
num1=int(input("enter number 1:"))
num2=int(input("enter number 2:"))
if num1>num2:
    print("number 1 is greater than number 2")
else:
    print("number 2 is greater than number 1")
# Out:
# number 1 is greater than number 2

# %% [markdown]
# ### if elif condition

# %%
num1=int(input("enter number 1:"))
num2=int(input("enter number 2:"))
if num1>num2:
    print("number 1 is greater than number 2")
elif num<num2:
     print("number 2 is greater than number 1")
else:
     print("number 1 and number 2 are equal")
# Out:
# number 1 is greater than number 2

# %%
#largest of three numbers

a=int(input("enter first number:"))
b=int(input("enter second number:"))
c=int(input("enter third number:"))
if a>b and a>c:
    print("a is largest")
elif b>a and b>c:
    print("b is largest")
else:
    print("c is largest")
# Out:
# c is largest

# %%
#traffic signal

signal=input("enter signal:").lower()
if signal=="red":
    print("stop")
elif signal=="yellow":
    print("slow")
elif signal=="green":
    print("go")
else:
    print("invalid input")
# Out:
# go

# %%
#grading

marks=int(input("enter marks:"))
if marks>=90:
    print("Grade A")
elif marks>=70:
    print("Grade B")
elif marks>=50:
    print("Grade C")
else:
    print("Failed")
# Out:
# Grade A

# %%
#eligiblity checking for scholarship

age=int(input("enter age:"))
income=int(input("enter income:"))
if age>=18 and income<=20000:
    print("eligible for scholarship")
else:
    print("not eligible")
# Out:
# eligible for scholarship

# %%
#eligiblity for interview

python=int(input("enter python marks:"))
excel=int(input("enter excel marks:"))
sql=int(input("enter sql marks:"))
if python<40 or excel<40 or sql<40:
    print("not eligible for interview")
else:
    print("eligible for interview")
# Out:
# not eligible for interview

# %% [markdown]
# ### nested if

# %% [markdown]
# check if a student passed and scored distinction

# %%
score=int(input("enter score:"))
if score>=30:
    if score>=90:
        print("passed with distinction")
    else:
        print("passed")
else:
    print("failed")
# Out:
# passed with distinction

# %%
c=input("enter character:").lower()
if c.isalpha():
    if c=="a" or c=="e" or c=="i" or  c=="o" or c=="u" :
        
        print("is vowel")
    else:
        print("consonant")
else:
    print('not char')
# Out:
# not char

# %%
num=int(input("enter number:"))
if num>0:
    if num%2==0:
        print(f"{num} is even and positive")
    else:
        print(f"{num} is odd and positive")
else:
    print("negative")
# Out:
# 2 is even and positive

# %%
age=int(input("enter age:"))
income=int(input("enter income:"))
if age>=18:
    if income<20000:
        print("eligible for scholarship")
    else:
        print("income higher! not eligible for schloarship")

else:
    print("not eligible ")
# Out:
# income higher! not eligible for schloarship

# %%
age=int(input("enter age:"))
citizen=input("Are you a citizen? Yes/No").lower()
if citizen=="yes":
    if age>=18:
        print("Eligible to vote")
    else:
        print("Not eligible")
else:
    print("not eligible")
# Out:
# Not eligible
